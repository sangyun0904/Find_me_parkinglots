# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("전국주차장정보표준데이터.csv")
df.head(10)
# Out:
#         주차장관리번호        주차장명 주차장구분 주차장유형                       소재지도로명주소  \
# 0  186-2-000015    신성동 제2공영    공영    노외                            NaN
# 1  186-2-000016  덕명지구 공영(1)    공영    노외                            NaN
# 2  186-2-000017  덕명지구 공영(2)    공영    노외                            NaN
# 3  186-2-000018  덕명지구 공영(3)    공영    노외                            NaN
# 4  186-2-000019  덕명지구 공영(4)    공영    노외                            NaN
# 5  186-2-000020  덕명지구 공영(5)    공영    노외                            NaN
# 6  186-2-000021  덕명지구 공영(6)    공영    노외                            NaN
# 7  186-2-000022      장대동 공영    공영    노외  대전광역시 유성구 유성대로729번길 40, (장대동)
# 8  186-2-000024   전민동주민센터공영    공영    노외                            NaN
# 9  186-2-000025    전민동 제1공영    공영    노외                            NaN
#
#                소재지지번주소  주차구획수 급지구분 부제시행구분        운영요일  ... 월정기권요금 결제방법 특기사항  \
# 0  대전광역시 유성구 신성동 211-2     70    2    미시행  평일+토요일+공휴일  ...    NaN  NaN  NaN
# ...

# %%
df.describe()
# Out:
#               주차구획수        주차기본시간         주차기본요금       추가단위시간   1일주차권요금적용시간  \
# count  14802.000000  14802.000000   14429.000000  6312.000000  4.497000e+03
# mean      62.580395     44.176699     392.910527    14.395002  2.415554e+04
# std      103.025310    408.526009    2964.846243    85.979174  4.649163e+05
# min        0.000000      0.000000       0.000000     0.000000  0.000000e+00
# 25%       17.000000      0.000000       0.000000     0.000000  0.000000e+00
# 50%       32.000000      0.000000       0.000000    10.000000  5.000000e+00
# 75%       69.000000     30.000000     400.000000    10.000000  2.400000e+01
# max     4261.000000  43200.000000  110000.000000  1440.000000  1.000220e+07
#
#              1일주차권요금         월정기권요금            위도            경도
# count    5059.000000    4815.000000  12368.000000  12358.000000
# mean     4685.882585   48199.185877     36.353924    127.674541
# std      8194.854119   43693.321667      1.100018      0.938795
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14802 entries, 0 to 14801
# Data columns (total 33 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   주차장관리번호      14802 non-null  object
#  1   주차장명         14802 non-null  object
#  2   주차장구분        14802 non-null  object
#  3   주차장유형        14802 non-null  object
#  4   소재지도로명주소     8207 non-null   object
#  5   소재지지번주소      13946 non-null  object
#  6   주차구획수        14802 non-null  int64
#  7   급지구분         14802 non-null  object
#  8   부제시행구분       14802 non-null  object
#  9   운영요일         14802 non-null  object
#  10  평일운영시작시각     14802 non-null  object
#  11  평일운영종료시각     14802 non-null  object
#  12  토요일운영시작시각    14802 non-null  object
#  13  토요일운영종료시각    14802 non-null  object
#  14  공휴일운영시작시각    14802 non-null  object
#  15  공휴일운영종료시각    14802 non-null  object
#  16  요금정보         14802 non-null  object
#  17  주차기본시간       14802 non-null  float64
# ...

# %%
df["주차장구분"].value_counts()
# Out:
# 공영    13795
# 민영     1007
# Name: 주차장구분, dtype: int64

# %%
df["주차장유형"].value_counts()
# Out:
# 노외    9980
# 노상    4301
# 부설     521
# Name: 주차장유형, dtype: int64

# %%
df["급지구분"].value_counts()
# Out:
# 1     6217
# 2     3720
# 기타    2164
# 3     1517
# 4      959
# 5      225
# Name: 급지구분, dtype: int64

# %%
df["부제시행구분"].value_counts()
# Out:
# 미시행     13958
# 요일제       805
# 5부제        31
# 2부제         7
# 10부제        1
# Name: 부제시행구분, dtype: int64

# %%
df["운영요일"].value_counts()
# Out:
# 평일+토요일+공휴일     12830
# 평일+토요일           924
# 평일               923
# 평일+토요일+ 공휴일       89
# 평일+공휴일            30
# 토요일+공휴일            4
# 공휴일                2
# Name: 운영요일, dtype: int64

# %%
df["평일운영시작시각"].head()
# Out:
# 0    00:00
# 1    00:00
# 2    00:00
# 3    00:00
# 4    00:00
# Name: 평일운영시작시각, dtype: object

# %%
df["요금정보"].value_counts()
# Out:
# 무료    9217
# 유료    4772
# 혼합     813
# Name: 요금정보, dtype: int64

# %%
df["주차기본시간"].value_counts()
# Out:
# 0.0        8538
# 30.0       3298
# 10.0        962
# 60.0        687
# 5.0         604
# 1440.0      300
# 20.0        142
# 24.0         96
# 180.0        77
# 1.0          34
# 15.0         30
# 120.0        12
# 45.0          4
# 0.5           3
# 480.0         3
# 40.0          2
# 2.0           2
# 600.0         2
# 510.0         2
# 90.0          1
# 420.0         1
# 540.0         1
# 43200.0       1
# Name: 주차기본시간, dtype: int64

# %%
df["결제방법"].value_counts()
# Out:
# 현금                 1322
# 신용카드                785
# 현금+신용카드             668
# 현금+카드               485
# 카드                  328
# 무료                  131
# 현금,신용카드             122
# 현금, 신용카드            113
# 0                    91
# 카드결제                 80
# 현금 카드                71
# 고지서+카드결제+자동이체        70
# 카드/현금/무통장/지로         54
# 현금,카드                54
# 계좌이체                 47
# 신용카드+교통카드            43
# 없음                   41
# 현금/계좌이체              35
# 카드+계좌이체              34
# 현금, 카드               31
# 현금/카드                28
# 현금,  신용카드            27
# 이체+신용카드              26
# 해당없음                 22
# 신용                   15
# 현금, 우대권              15
# 카드+현금                14
# 신용카드+현금              14
# 현금+우대권               11
# 현금. 신용카드              9
# N                     9
# 현금+카드(월정기만)           8
# 현금+신용카드+하이패스          7
# 카드+현금+주차할인권           6
# 현금 + 신용카드             5
# 현금,계좌이체               5
# 신용카드(무인)              4
# 현금,계좌이체,카드            4
# ...

# %%
public = {"공영":True, "민영":False}

# %%
df["주차장구분"] = df["주차장구분"].map(public)

# %%
df.head()
# Out:
#         주차장관리번호        주차장명  주차장구분 주차장유형 소재지도로명주소              소재지지번주소  주차구획수  \
# 0  186-2-000015    신성동 제2공영   True    노외      NaN  대전광역시 유성구 신성동 211-2     70
# 1  186-2-000016  덕명지구 공영(1)   True    노외      NaN    대전광역시 유성구 덕명동 544     30
# 2  186-2-000017  덕명지구 공영(2)   True    노외      NaN    대전광역시 유성구 구암동 657     19
# 3  186-2-000018  덕명지구 공영(3)   True    노외      NaN    대전광역시 유성구 구암동 677     17
# 4  186-2-000019  덕명지구 공영(4)   True    노외      NaN    대전광역시 유성구 덕명동 544     29
#
#   급지구분 부제시행구분        운영요일  ... 월정기권요금 결제방법 특기사항       관리기관명          전화번호  \
# 0    2    미시행  평일+토요일+공휴일  ...    NaN  NaN  NaN  대전광역시 유성구청  042-611-2956
# 1    2    미시행  평일+토요일+공휴일  ...    NaN  NaN  NaN  대전광역시 유성구청  042-611-2956
# 2    1    미시행  평일+토요일+공휴일  ...    NaN  NaN  NaN  대전광역시 유성구청  042-611-2956
# 3    1    미시행  평일+토요일+공휴일  ...    NaN  NaN  NaN  대전광역시 유성구청  042-611-2956
# 4    2    미시행  평일+토요일+공휴일  ...    NaN  NaN  NaN  대전광역시 유성구청  042-611-2956
#
# ...

# %%
c = df.columns[:-3]

# %%
df = df[c]
df.head(10)
# Out:
#         주차장관리번호        주차장명  주차장구분 주차장유형                       소재지도로명주소  \
# 0  186-2-000015    신성동 제2공영   True    노외                            NaN
# 1  186-2-000016  덕명지구 공영(1)   True    노외                            NaN
# 2  186-2-000017  덕명지구 공영(2)   True    노외                            NaN
# 3  186-2-000018  덕명지구 공영(3)   True    노외                            NaN
# 4  186-2-000019  덕명지구 공영(4)   True    노외                            NaN
# 5  186-2-000020  덕명지구 공영(5)   True    노외                            NaN
# 6  186-2-000021  덕명지구 공영(6)   True    노외                            NaN
# 7  186-2-000022      장대동 공영   True    노외  대전광역시 유성구 유성대로729번길 40, (장대동)
# 8  186-2-000024   전민동주민센터공영   True    노외                            NaN
# 9  186-2-000025    전민동 제1공영   True    노외                            NaN
#
#                소재지지번주소  주차구획수 급지구분 부제시행구분        운영요일  ... 추가단위요금 1일주차권요금적용시간  \
# 0  대전광역시 유성구 신성동 211-2     70    2    미시행  평일+토요일+공휴일  ...    NaN         NaN
# ...

# %%
df.to_csv('./parkinglots.csv', sep=",",na_rep="NAN", encoding="UTF-8")

# %%
columns = ["p_id", "p_name", "p_long", "p_lat", "p_num"]

# %%
df = df[["주차장관리번호", "주차장명", "위도", "경도", "주차구획수"]]
df.head()
# Out:
#         주차장관리번호        주차장명         위도          경도  주차구획수
# 0  186-2-000015    신성동 제2공영  36.388520  127.348863     70
# 1  186-2-000016  덕명지구 공영(1)  36.356774  127.310327     30
# 2  186-2-000017  덕명지구 공영(2)  36.360501  127.308142     19
# 3  186-2-000018  덕명지구 공영(3)  36.358604  127.309319     17
# 4  186-2-000019  덕명지구 공영(4)  36.356774  127.310327     29

# %%
df.columns = columns
df.head()
# Out:
#            p_id      p_name     p_long       p_lat  p_num
# 0  186-2-000015    신성동 제2공영  36.388520  127.348863     70
# 1  186-2-000016  덕명지구 공영(1)  36.356774  127.310327     30
# 2  186-2-000017  덕명지구 공영(2)  36.360501  127.308142     19
# 3  186-2-000018  덕명지구 공영(3)  36.358604  127.309319     17
# 4  186-2-000019  덕명지구 공영(4)  36.356774  127.310327     29
